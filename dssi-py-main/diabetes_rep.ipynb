# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from joblib import dump, load
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import RandomForestClassifier

sns.set_theme(style="ticks", palette="pastel")

def remove_outliers(df, col: str):
    q3 = np.quantile(df[col], 0.75)
    q1 = np.quantile(df[col], 0.25)
    l_lmt = q1 - 1.5 * (q3 - q1)
    u_lmt = q3 + 1.5 * (q3 - q1)
    return df[(df[col] >= l_lmt) & (df[col] <= u_lmt)].copy()
    
#Read Sample Dataset
raw_df = pd.read_csv('/Users/xiezhuoying/Desktop/NUS/DSSI/Day_2/dssi-py-main/diabetes.csv')
raw_df.head()
# Out:
#    sn  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6    148.0           72.0             35        0  33.6
# 1   2            1     85.0           66.0             29        0  26.6
# 2   3            8    183.0           64.0              0        0  23.3
# 3   4            1     89.0           66.0             23       94  28.1
# 4   5            0    137.0           40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Check of missing values
raw_df.isnull().sum()
# Out:
# sn                           0
# Pregnancies                  0
# Glucose                      5
# BloodPressure               35
# SkinThickness                0
# Insulin                      0
# BMI                         11
# DiabetesPedigreeFunction     0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
glucose_avg = raw_df['Glucose'].mean()
blood_pressure_avg = raw_df['BloodPressure'].mean()
bmi_avg = raw_df['BMI'].mean()

raw_df['Glucose'].fillna(glucose_avg, inplace=True)
raw_df['BloodPressure'].fillna(blood_pressure_avg, inplace=True)
raw_df['BMI'].fillna(bmi_avg, inplace=True)

print(raw_df.isnull().sum())
# Out:
# sn                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
raw_df.describe(include='all')
# Out:
#                sn  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# count  768.000000   768.000000  768.000000     768.000000     768.000000
# mean   384.500000     3.845052  121.686763      72.405184      20.536458
# std    221.846794     3.369578   30.435949      12.096346      15.952218
# min      1.000000     0.000000   44.000000      24.000000       0.000000
# 25%    192.750000     1.000000   99.750000      64.000000       0.000000
# 50%    384.500000     3.000000  117.000000      72.202592      23.000000
# 75%    576.250000     6.000000  140.250000      80.000000      32.000000
# max    768.000000    17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigreeFunction         Age  \
# count  768.000000  768.000000                768.000000  768.000000
# mean    79.799479   32.457464                  0.471876   33.240885
# std    115.244002    6.875151                  0.331329   11.760232
# min      0.000000   18.200000                  0.078000   21.000000
# 25%      0.000000   27.500000                  0.243750   24.000000
# 50%     30.500000   32.400000                  0.372500   29.000000
# 75%    127.250000   36.600000                  0.626250   41.000000
# max    846.000000   67.100000                  2.420000   81.000000
#
#           Outcome
# count  768.000000
# mean     0.348958
# std      0.476951
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
label = 'Outcome'

# %%
X_train, X_test, y_train, y_test = train_test_split(raw_df[features], \
                                                    raw_df[label], \
                                                    test_size=0.2, \
                                                    random_state=0)
X_train.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 603            7    150.0      78.000000             29      126  35.2
# 118            4     97.0      60.000000             23        0  28.2
# 247            0    165.0      90.000000             33      680  52.3
# 157            1    109.0      56.000000             21      135  25.2
# 468            8    120.0      72.405184              0        0  30.0
#
#      DiabetesPedigreeFunction  Age
# 603                     0.692   54
# 118                     0.443   22
# 247                     0.427   23
# 157                     0.833   23
# 468                     0.183   38

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

rf_model = RandomForestClassifier(n_estimators=100, random_state=0)  # n_estimators 是树的数量

rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7987012987012987
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       107
#            1       0.68      0.64      0.66        47
#
#     accuracy                           0.80       154
#    macro avg       0.76      0.75      0.76       154
# weighted avg       0.80      0.80      0.80       154
